# %%
from slsim.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing
import numpy as np
from astropy.cosmology import FlatLambdaCDM
# Out:
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=50, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=1.5E+11, m_max=None, z_max=1.5)
# Out:
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()

# %%
from slsim.Halos.halos_lens import HalosLens
from slsim.Halos.halos_plus_glass import run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=50, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=1.5E+11, m_max=None, z_max=1.5, zs=1.5, zd=0.5)

print(distribution)
# Out:
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

nk1 = [point[0] for point in distribution]
ng1 = [point[1] for point in distribution]

total_plot = sns.jointplot(x=nk1, y=ng1,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values with correction")
plt.show()

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=70, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=5E+10, m_max=None, z_max=1.5)
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()

from slsim.Halos.halos_plus_glass import run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=70, sky_area=0.0001, samples_number=2,cosmo=cosmo,  m_min=5E+10, m_max=None, z_max=1.5, zs=1.5, zd=0.5)

nk1 = [point[0] for point in distribution]
ng1 = [point[1] for point in distribution]

total_plot = sns.jointplot(x=nk1, y=ng1,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values with correction")
plt.show()
# Out:
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# ...

# %%
print(distribution)
# Out:
# [array([-0.11975579,  0.00365259]), array([-0.12168208,  0.00397711]), array([-0.12237608,  0.00532843]), array([-0.12110757,  0.00180323]), array([-0.07631442,  0.03392827]), array([-0.01198531,  0.05448544]), array([-0.12142624,  0.00577089]), array([-0.12205862,  0.00202416]), array([-0.09828706,  0.01616692]), array([-0.10517324,  0.0089618 ]), array([-0.1156231 ,  0.01171974]), array([-0.11453017,  0.00959019]), array([-0.12086751,  0.00242796]), array([-0.1152902 ,  0.00290151]), array([-0.06686338,  0.01118434]), array([-0.09426697,  0.00767976]), array([-0.11696087,  0.00482164]), array([-0.12015331,  0.00645403]), array([-0.11337685,  0.00750079]), array([-0.12088947,  0.00440494]), array([-0.11538352,  0.01198793]), array([-0.10683417,  0.01333058]), array([-0.10329877,  0.02358343]), array([-0.09910111,  0.0234463 ]), array([-0.12260594,  0.00405349]), array([-0.1082853 ,  0.00874791]), array([-0.09120667,  0.02327014]), array([-0.06675387,  0.01699339]), array([-0.0478549
# ...

# %%
import pandas as pd

df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})

# Concatenate DataFrames
df_total = pd.concat([df1, df2], axis=0)

import seaborn as sns

sns.jointplot(data=df_total, x="x", y="y", hue="type", kind="kde")
plt.title('z_max=1.5, zs=1.5')
plt.show()

# %%
import pandas as pd
import numpy as np
from slsim.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing, run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM,default_cosmology
import seaborn as sns
import matplotlib.pyplot as plt

def plot_kappa_gamma(zs=1.5, zd=0.5, n_iterations=100, sky_area=0.00082, samples_number=30, m_min='1.0E+12', m_max='1.0E+16'):
    # Setup Cosmology
    cosmo = default_cosmology.get()
    # Without Correction
    nk, ng = run_halos_without_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, listmean=False)
    nk_mean = sum(nk) / len(nk)
    print(f"zs={zs}, zd={zd},k_s_mean={nk_mean}")
    nk = [item - nk_mean for item in nk]

    # With Correction
    distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, zs=zs, zd=zd, listmean=False)
    nk1 = [point[0] for point in distribution]
    ng1 = [point[1] for point in distribution]
    nk1_mean = sum(nk1) / len(nk1)
    print(f"zs={zs}, zd={zd},k_ext_mean={nk1_mean}")
    nk1 = [item - nk1_mean for item in nk1]


    # Combine Data for Joint KDE Plot
    df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
    df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})
    df_total = pd.concat([df1, df2], axis=0)

    var_nk = np.var(nk)
    var_nk1 = np.var(nk1)
    print(f"Variance of k_S: {var_nk}")
    print(f"Variance of k_ext: {var_nk1}")

    # Plotting
    plot = sns.jointplot(data=df_total, x="x", y="y", hue="type", kind="kde")

    plot.ax_joint.set_xlabel("kappa")
    plot.ax_joint.set_ylabel("gamma")
    m_min_float = float(m_min)
    plt.title(f'zs={zs}, zd={zd}, mean=0')
    plot.fig.suptitle(f"zs={zs}, zd={zd}, m=10^{np.log10(m_min_float)}, mean=0, with mass-sheet")
   # plot.ax_joint.set_xlim(-0.2, 0.2)

    plt.show()

# To use the function:
plot_kappa_gamma(zs=1.5, zd=0.5,m_min='1.0E+12', m_max='1.0E+16')
plot_kappa_gamma(zs=2.5, zd=0.5,m_min='1.0E+12', m_max='1.0E+16')
plot_kappa_gamma(zs=1.0, zd=0.5,m_min='1.0E+12', m_max='1.0E+16')
# Out:
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /Users/tz/Documents/GitHub/slsim/venv/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# ...

# %%
import pandas as pd
from slsim.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing, run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM,default_cosmology
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

def plot_kappa_gamma2(zs=1.5, zd=0.1, n_iterations=180, sky_area=0.00082, samples_number=40, m_min='1E+12', m_max='1E+16'):
    # Setup Cosmology
    cosmo = default_cosmology.get()
    # Without Correction
    nk, ng = run_halos_without_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs,mass_sheet_correction=False, listmean=False, )
    nk_mean = sum(nk) / len(nk)
    nk = [item - nk_mean for item in nk]
    
    # With Correction
    distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, zs=zs, zd=zd,mass_sheet_correction=False, listmean=False)
    nk1 = [point[0] for point in distribution]
    ng1 = [point[1] for point in distribution]
    nk1_mean = sum(nk1) / len(nk1)
    nk1 = [item - nk1_mean for item in nk1]
    
    
    # Combine Data for Joint KDE Plot
    df1 = pd.DataFrame({'x': nk, 'y': ng, 'type': 'Without Correction'})
    df2 = pd.DataFrame({'x': nk1, 'y': ng1, 'type': 'With LOS Correction'})
    df_total = pd.concat([df1, df2], axis=0)
    m_min_float = float(m_min)

    # Plotting
    plot = sns.jointplot(data=df_total, x="x", y="y",  hue="type", kind="kde")
    plot.fig.suptitle(f"zs={zs}, zd={zd},, m=10^{np.log10(m_min_float)}, mean=0, without mass-sheet")
    plot.ax_joint.set_xlim(-0.2, 0.2)
    plt.show()

# %%
plot_kappa_gamma2(zs=0.2, zd=0.1, m_min='1.0E+12', m_max='1.0E+16')

#plot_kappa_gamma2(zs=3.5, zd=1.5, m_min='1.0E+12', m_max='1.0E+16')

plot_kappa_gamma2(zs=1.5, zd=1.0, m_min='1.0E+12', m_max='1.0E+16')

# %%
plot_kappa_gamma2(zs=4.5, zd=1.5, m_min='1.0E+12', m_max='1.0E+16')

# %%
import pandas as pd
import numpy as np
from slsim.Halos.halos_plus_glass import run_halos_without_kde_by_multiprocessing, run_certain_redshift_lensext_kde_by_multiprocessing
from astropy.cosmology import FlatLambdaCDM,default_cosmology
import seaborn as sns
import matplotlib.pyplot as plt

def test_kappa_gamma(zs=1.5, zd=0.5, n_iterations=500, sky_area=0.0001, samples_number=3, m_min='1.0E+12', m_max='1.0E+16'):
    # Setup Cosmology
    cosmo = default_cosmology.get()
    # With Correction
    distribution = run_certain_redshift_lensext_kde_by_multiprocessing(n_iterations=n_iterations, sky_area=sky_area, samples_number=samples_number, cosmo=cosmo, m_min=m_min, m_max=m_max, z_max=zs, zs=zs, zd=zd, listmean=False)
    
    return distribution

dis = test_kappa_gamma()

# %%
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=200, sky_area=0.00082, samples_number=20,cosmo=cosmo,  m_min=1E+12, m_max=None, z_max=1.5,mass_sheet_correction=False)
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()

# %%
nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=200, sky_area=0.00082, samples_number=20,cosmo=cosmo,  m_min=1E+12, m_max=None, z_max=2.5,mass_sheet_correction=False)
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()

# %%
nk,ng = run_halos_without_kde_by_multiprocessing(n_iterations=200, sky_area=0.00082, samples_number=20,cosmo=cosmo,  m_min=1E+12, m_max=None, z_max=5,mass_sheet_correction=False)
import seaborn as sns
import matplotlib.pyplot as plt

total_plot = sns.jointplot(x=nk, y=ng,kind='hex')
total_plot.plot_joint(sns.kdeplot, color="r", zorder=3, levels=5)
total_plot.ax_joint.set_xlabel('kappa', fontweight='bold')
total_plot.ax_joint.set_ylabel('gamma', fontweight='bold')
total_plot.fig.suptitle("Kappa and Gamma values without correction")
plt.show()
